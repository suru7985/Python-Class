# %%
import pandas as pd

# %%
df = pd.read_csv('flipkart_laptop_Aug_22.csv')
df
# Out:
#      Unnamed: 0                                              title      price  \
# 0             0  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...    ₹38,990
# 1             1  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...    ₹54,990
# 2             2  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹35,990
# 3             3  ASUS Vivobook 15 Ryzen 7 Quad Core AMD R7-3700...    ₹46,990
# 4             4  MSI Modern 14 Core i5 10th Gen - (8 GB/512 GB ...    ₹41,990
# ..          ...                                                ...        ...
# 200         200  ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 ...    ₹50,990
# 201         201  ASUS ZenBook Duo 14 (2021) Touch Panel Intel E...  ₹1,14,990
# 202         202  acer Aspire 5 Core i5 11th Gen - (8 GB/512 GB ...    ₹59,090
# 203         203  DELL Inspiron Core i3 11th Gen - (8 GB/256 GB ...    ₹55,490
# 204         204  HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...    ₹41,290
#
#                               rr  \
# 0    1,260 Ratings & 125 Reviews
# 1       188 Ratings & 17 Reviews
# 2    2,246 Ratings & 258 Reviews
# 3         63 Ratings & 4 Reviews
# 4      867 Ratings & 108 Reviews
# ..                           ...
# 200  1,768 Ratings & 174 Reviews
# 201       12 Ratings & 2 Reviews
# 202     284 Ratings & 30 Reviews
# 203     222 Ratings & 21 Reviews
# 204  2,112 Ratings & 229 Reviews
#
#                                                   link  \
# 0    /lenovo-ideapad-3-core-i3-11th-gen-8-gb-512-gb...
# 1    /lenovo-ideapad-gaming-core-i5-11th-gen-8-gb-5...
# 2    /asus-vivobook-15-2022-core-i3-10th-gen-8-gb-5...
# 3    /asus-vivobook-15-ryzen-7-quad-core-amd-r7-370...
# 4    /msi-modern-14-core-i5-10th-gen-8-gb-512-gb-ss...
# ..                                                 ...
# 200  /asus-vivobook-15-2022-core-i5-11th-gen-8-gb-1...
# 201  /asus-zenbook-duo-14-2021-touch-panel-intel-ev...
# 202  /acer-aspire-5-core-i5-11th-gen-8-gb-512-gb-ss...
# 203  /dell-inspiron-core-i3-11th-gen-8-gb-256-gb-ss...
# 204  /hp-core-i3-11th-gen-8-gb-256-gb-ssd-windows-1...
#
#                                               img_link  \
# 0    https://rukminim1.flixcart.com/image/312/312/k...
# 1    https://rukminim1.flixcart.com/image/312/312/k...
# 2    https://rukminim1.flixcart.com/image/312/312/k...
# 3    https://rukminim1.flixcart.com/image/312/312/l...
# 4    https://rukminim1.flixcart.com/image/312/312/k...
# ..                                                 ...
# 200  https://rukminim1.flixcart.com/image/312/312/k...
# 201  https://rukminim1.flixcart.com/image/312/312/k...
# 202  https://rukminim1.flixcart.com/image/312/312/k...
# 203  https://rukminim1.flixcart.com/image/312/312/l...
# 204  https://rukminim1.flixcart.com/image/312/312/l...
#
#                                                details
# 0    Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 1    Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 2    Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3    AMD Ryzen 7 Quad Core Processor16 GB DDR4 RAM6...
# 4    Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...
# ..                                                 ...
# 200  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 201  Intel Core i7 Processor (11th Gen)16 GB LPDDR4...
# 202  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 203  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 204  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
#
# [205 rows x 7 columns]

# %%
df = pd.read_csv('flipkart_laptop_Aug_22.csv',index_col=0)
df
# Out:
#                                                  title      price  \
# 0    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...    ₹38,990
# 1    Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...    ₹54,990
# 2    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹35,990
# 3    ASUS Vivobook 15 Ryzen 7 Quad Core AMD R7-3700...    ₹46,990
# 4    MSI Modern 14 Core i5 10th Gen - (8 GB/512 GB ...    ₹41,990
# ..                                                 ...        ...
# 200  ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 ...    ₹50,990
# 201  ASUS ZenBook Duo 14 (2021) Touch Panel Intel E...  ₹1,14,990
# 202  acer Aspire 5 Core i5 11th Gen - (8 GB/512 GB ...    ₹59,090
# 203  DELL Inspiron Core i3 11th Gen - (8 GB/256 GB ...    ₹55,490
# 204  HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...    ₹41,290
#
#                               rr  \
# 0    1,260 Ratings & 125 Reviews
# 1       188 Ratings & 17 Reviews
# 2    2,246 Ratings & 258 Reviews
# 3         63 Ratings & 4 Reviews
# 4      867 Ratings & 108 Reviews
# ..                           ...
# 200  1,768 Ratings & 174 Reviews
# 201       12 Ratings & 2 Reviews
# 202     284 Ratings & 30 Reviews
# 203     222 Ratings & 21 Reviews
# 204  2,112 Ratings & 229 Reviews
#
#                                                   link  \
# 0    /lenovo-ideapad-3-core-i3-11th-gen-8-gb-512-gb...
# 1    /lenovo-ideapad-gaming-core-i5-11th-gen-8-gb-5...
# 2    /asus-vivobook-15-2022-core-i3-10th-gen-8-gb-5...
# 3    /asus-vivobook-15-ryzen-7-quad-core-amd-r7-370...
# 4    /msi-modern-14-core-i5-10th-gen-8-gb-512-gb-ss...
# ..                                                 ...
# 200  /asus-vivobook-15-2022-core-i5-11th-gen-8-gb-1...
# 201  /asus-zenbook-duo-14-2021-touch-panel-intel-ev...
# 202  /acer-aspire-5-core-i5-11th-gen-8-gb-512-gb-ss...
# 203  /dell-inspiron-core-i3-11th-gen-8-gb-256-gb-ss...
# 204  /hp-core-i3-11th-gen-8-gb-256-gb-ssd-windows-1...
#
#                                               img_link  \
# 0    https://rukminim1.flixcart.com/image/312/312/k...
# 1    https://rukminim1.flixcart.com/image/312/312/k...
# 2    https://rukminim1.flixcart.com/image/312/312/k...
# 3    https://rukminim1.flixcart.com/image/312/312/l...
# 4    https://rukminim1.flixcart.com/image/312/312/k...
# ..                                                 ...
# 200  https://rukminim1.flixcart.com/image/312/312/k...
# 201  https://rukminim1.flixcart.com/image/312/312/k...
# 202  https://rukminim1.flixcart.com/image/312/312/k...
# 203  https://rukminim1.flixcart.com/image/312/312/l...
# 204  https://rukminim1.flixcart.com/image/312/312/l...
#
#                                                details
# 0    Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 1    Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 2    Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3    AMD Ryzen 7 Quad Core Processor16 GB DDR4 RAM6...
# 4    Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...
# ..                                                 ...
# 200  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 201  Intel Core i7 Processor (11th Gen)16 GB LPDDR4...
# 202  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 203  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 204  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
#
# [205 rows x 6 columns]

# %%
df = pd.read_csv('flipkart_laptop_Aug_22.csv',usecols=['title,price'])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\shruti\Documents\Python Class\DataScience\data_science\data_analysis2.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shruti/Documents/Python%20Class/DataScience/data_science/data_analysis2.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv('flipkart_laptop_Aug_22.csv',usecols=['title,price'])
#       <a href='vscode-notebook-cell:/c%3A/Users/shruti/Documents/Python%20Class/DataScience/data_science/data_analysis2.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> df
#
# File c:\Users\shruti\miniconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\shruti\miniconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\shruti\miniconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Users\shruti\miniconda3\lib\site-packages\pandas\io\parsers\readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\shruti\miniconda3\lib\site-packages\pandas\io\parsers\readers.py:1236, in TextFileReader._make_engine(self, f, engine)
#    1233     raise ValueError(msg)
#    1235 try:
# -> 1236     return mapping[engine](f, **self.options)
#    1237 except Exception:
#    1238     if self.handles is not None:
#
# File c:\Users\shruti\miniconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:131, in CParserWrapper.__init__(self, src, **kwds)
#     127 assert self.orig_names is not None
#     128 if self.usecols_dtype == "string" and not set(usecols).issubset(
#     129     self.orig_names
#     130 ):
# --> 131     self._validate_usecols_names(usecols, self.orig_names)
#     133 # error: Cannot determine type of 'names'
#     134 if len(self.names) > len(usecols):  # type: ignore[has-type]
#     135     # error: Cannot determine type of 'names'
#
# File c:\Users\shruti\miniconda3\lib\site-packages\pandas\io\parsers\base_parser.py:913, in ParserBase._validate_usecols_names(self, usecols, names)
#     911 missing = [c for c in usecols if c not in names]
#     912 if len(missing) > 0:
# --> 913     raise ValueError(
#     914         f"Usecols do not match columns, columns expected but not found: "
#     915         f"{missing}"
#     916     )
#     918 return usecols
#
# ValueError: Usecols do not match columns, columns expected but not found: ['title,price']

# %%
df.head() #first 5 rows
# Out:
#                                                title    price  \
# 0  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...  ₹38,990
# 1  Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...  ₹54,990
# 2  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...  ₹35,990
# 3  ASUS Vivobook 15 Ryzen 7 Quad Core AMD R7-3700...  ₹46,990
# 4  MSI Modern 14 Core i5 10th Gen - (8 GB/512 GB ...  ₹41,990
#
#                             rr  \
# 0  1,260 Ratings & 125 Reviews
# 1     188 Ratings & 17 Reviews
# 2  2,246 Ratings & 258 Reviews
# 3       63 Ratings & 4 Reviews
# 4    867 Ratings & 108 Reviews
#
#                                                 link  \
# 0  /lenovo-ideapad-3-core-i3-11th-gen-8-gb-512-gb...
# 1  /lenovo-ideapad-gaming-core-i5-11th-gen-8-gb-5...
# 2  /asus-vivobook-15-2022-core-i3-10th-gen-8-gb-5...
# 3  /asus-vivobook-15-ryzen-7-quad-core-amd-r7-370...
# 4  /msi-modern-14-core-i5-10th-gen-8-gb-512-gb-ss...
#
#                                             img_link  \
# 0  https://rukminim1.flixcart.com/image/312/312/k...
# 1  https://rukminim1.flixcart.com/image/312/312/k...
# 2  https://rukminim1.flixcart.com/image/312/312/k...
# 3  https://rukminim1.flixcart.com/image/312/312/l...
# 4  https://rukminim1.flixcart.com/image/312/312/k...
#
#                                              details
# 0  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 1  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3  AMD Ryzen 7 Quad Core Processor16 GB DDR4 RAM6...
# 4  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...

# %%
df.tail(6)
# Out:
#                                                  title      price  \
# 199  Lenovo IdeaPad 5 Pro Core i5 11th Gen - (16 GB...    ₹67,990
# 200  ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 ...    ₹50,990
# 201  ASUS ZenBook Duo 14 (2021) Touch Panel Intel E...  ₹1,14,990
# 202  acer Aspire 5 Core i5 11th Gen - (8 GB/512 GB ...    ₹59,090
# 203  DELL Inspiron Core i3 11th Gen - (8 GB/256 GB ...    ₹55,490
# 204  HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...    ₹41,290
#
#                               rr  \
# 199       17 Ratings & 2 Reviews
# 200  1,768 Ratings & 174 Reviews
# 201       12 Ratings & 2 Reviews
# 202     284 Ratings & 30 Reviews
# 203     222 Ratings & 21 Reviews
# 204  2,112 Ratings & 229 Reviews
#
#                                                   link  \
# 199  /lenovo-ideapad-5-pro-core-i5-11th-gen-16-gb-5...
# 200  /asus-vivobook-15-2022-core-i5-11th-gen-8-gb-1...
# 201  /asus-zenbook-duo-14-2021-touch-panel-intel-ev...
# 202  /acer-aspire-5-core-i5-11th-gen-8-gb-512-gb-ss...
# 203  /dell-inspiron-core-i3-11th-gen-8-gb-256-gb-ss...
# 204  /hp-core-i3-11th-gen-8-gb-256-gb-ssd-windows-1...
#
#                                               img_link  \
# 199  https://rukminim1.flixcart.com/image/312/312/k...
# 200  https://rukminim1.flixcart.com/image/312/312/k...
# 201  https://rukminim1.flixcart.com/image/312/312/k...
# 202  https://rukminim1.flixcart.com/image/312/312/k...
# 203  https://rukminim1.flixcart.com/image/312/312/l...
# 204  https://rukminim1.flixcart.com/image/312/312/l...
#
#                                                details
# 199  Intel Core i5 Processor (11th Gen)16 GB DDR4 R...
# 200  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 201  Intel Core i7 Processor (11th Gen)16 GB LPDDR4...
# 202  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...
# 203  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 204  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     205 non-null    object
#  1   price     205 non-null    object
#  2   rr        205 non-null    object
#  3   link      205 non-null    object
#  4   img_link  205 non-null    object
#  5   details   205 non-null    object
# dtypes: object(6)
# memory usage: 11.2+ KB

# %%
df.describe()
# Out:
#                                                     title    price  \
# count                                                 205      205
# unique                                                181      126
# top     ASUS ROG Strix G15 Ryzen 9 Octa Core 5900HX - ...  ₹34,990
# freq                                                    3        7
#
#                            rr  \
# count                     205
# unique                    163
# top     3 Ratings & 0 Reviews
# freq                        5
#
#                                                      link  \
# count                                                 205
# unique                                                205
# top     /lenovo-ideapad-3-core-i3-11th-gen-8-gb-512-gb...
# freq                                                    1
#
#                                                  img_link  \
# count                                                 205
# unique                                                139
# top     https://rukminim1.flixcart.com/image/312/312/k...
# freq                                                   16
#
#                                                   details
# count                                                 205
# unique                                                176
# top     AMD Ryzen 9 Octa Core Processor16 GB DDR4 RAMW...
# freq                                                    3

# %% [markdown]
# data manipulation

# %%
# 1. renaming columns
df.rename({'details':'configuration','title':'product_name'}, axis=1, inplace=True)

# %%
# 2. adding column
df['website'] = 'flipkart'

# %%
df
# Out:
#                                           product_name      price  \
# 0    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...    ₹38,990
# 1    Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...    ₹54,990
# 2    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹35,990
# 3    ASUS Vivobook 15 Ryzen 7 Quad Core AMD R7-3700...    ₹46,990
# 4    MSI Modern 14 Core i5 10th Gen - (8 GB/512 GB ...    ₹41,990
# ..                                                 ...        ...
# 200  ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 ...    ₹50,990
# 201  ASUS ZenBook Duo 14 (2021) Touch Panel Intel E...  ₹1,14,990
# 202  acer Aspire 5 Core i5 11th Gen - (8 GB/512 GB ...    ₹59,090
# 203  DELL Inspiron Core i3 11th Gen - (8 GB/256 GB ...    ₹55,490
# 204  HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...    ₹41,290
#
#                               rr  \
# 0    1,260 Ratings & 125 Reviews
# 1       188 Ratings & 17 Reviews
# 2    2,246 Ratings & 258 Reviews
# 3         63 Ratings & 4 Reviews
# 4      867 Ratings & 108 Reviews
# ..                           ...
# 200  1,768 Ratings & 174 Reviews
# 201       12 Ratings & 2 Reviews
# 202     284 Ratings & 30 Reviews
# 203     222 Ratings & 21 Reviews
# 204  2,112 Ratings & 229 Reviews
#
#                                                   link  \
# 0    /lenovo-ideapad-3-core-i3-11th-gen-8-gb-512-gb...
# 1    /lenovo-ideapad-gaming-core-i5-11th-gen-8-gb-5...
# 2    /asus-vivobook-15-2022-core-i3-10th-gen-8-gb-5...
# 3    /asus-vivobook-15-ryzen-7-quad-core-amd-r7-370...
# 4    /msi-modern-14-core-i5-10th-gen-8-gb-512-gb-ss...
# ..                                                 ...
# 200  /asus-vivobook-15-2022-core-i5-11th-gen-8-gb-1...
# 201  /asus-zenbook-duo-14-2021-touch-panel-intel-ev...
# 202  /acer-aspire-5-core-i5-11th-gen-8-gb-512-gb-ss...
# 203  /dell-inspiron-core-i3-11th-gen-8-gb-256-gb-ss...
# 204  /hp-core-i3-11th-gen-8-gb-256-gb-ssd-windows-1...
#
#                                               img_link  \
# 0    https://rukminim1.flixcart.com/image/312/312/k...
# 1    https://rukminim1.flixcart.com/image/312/312/k...
# 2    https://rukminim1.flixcart.com/image/312/312/k...
# 3    https://rukminim1.flixcart.com/image/312/312/l...
# 4    https://rukminim1.flixcart.com/image/312/312/k...
# ..                                                 ...
# 200  https://rukminim1.flixcart.com/image/312/312/k...
# 201  https://rukminim1.flixcart.com/image/312/312/k...
# 202  https://rukminim1.flixcart.com/image/312/312/k...
# 203  https://rukminim1.flixcart.com/image/312/312/l...
# 204  https://rukminim1.flixcart.com/image/312/312/l...
#
#                                          configuration   website
# 0    Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...  flipkart
# 1    Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...  flipkart
# 2    Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...  flipkart
# 3    AMD Ryzen 7 Quad Core Processor16 GB DDR4 RAM6...  flipkart
# 4    Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...  flipkart
# ..                                                 ...       ...
# 200  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...  flipkart
# 201  Intel Core i7 Processor (11th Gen)16 GB LPDDR4...  flipkart
# 202  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...  flipkart
# 203  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...  flipkart
# 204  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...  flipkart
#
# [205 rows x 7 columns]

# %%
import numpy as np

def extract_rating(value):
    if value:
        value_0 = value.split()[0]
        value_0 = value_0.replace(',','')
        return int(value_0)
    else:
        return np.nan

def extract_reviews(value):
    try:
        return int(value.split()[-2].replace(',',''))
    except:
        return 0

# 3. adding columns with functions
df['ratings'] = df['rr'].apply(extract_rating)
df['reviews'] = df['rr'].apply(extract_reviews)

# %%
# 4. dropting columns
df.drop(columns=['rr'], inplace=True)

# %%
# Task 1: create a column brand and store the brand name in it taken from the first column
df['brand'] = df['product_name'].apply(lambda x: x.split()[0])

# %%
df
# Out:
#                                           product_name      price  \
# 0    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...    ₹38,990
# 1    Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...    ₹54,990
# 2    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    ₹35,990
# 3    ASUS Vivobook 15 Ryzen 7 Quad Core AMD R7-3700...    ₹46,990
# 4    MSI Modern 14 Core i5 10th Gen - (8 GB/512 GB ...    ₹41,990
# ..                                                 ...        ...
# 200  ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 ...    ₹50,990
# 201  ASUS ZenBook Duo 14 (2021) Touch Panel Intel E...  ₹1,14,990
# 202  acer Aspire 5 Core i5 11th Gen - (8 GB/512 GB ...    ₹59,090
# 203  DELL Inspiron Core i3 11th Gen - (8 GB/256 GB ...    ₹55,490
# 204  HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...    ₹41,290
#
#                                                   link  \
# 0    /lenovo-ideapad-3-core-i3-11th-gen-8-gb-512-gb...
# 1    /lenovo-ideapad-gaming-core-i5-11th-gen-8-gb-5...
# 2    /asus-vivobook-15-2022-core-i3-10th-gen-8-gb-5...
# 3    /asus-vivobook-15-ryzen-7-quad-core-amd-r7-370...
# 4    /msi-modern-14-core-i5-10th-gen-8-gb-512-gb-ss...
# ..                                                 ...
# 200  /asus-vivobook-15-2022-core-i5-11th-gen-8-gb-1...
# 201  /asus-zenbook-duo-14-2021-touch-panel-intel-ev...
# 202  /acer-aspire-5-core-i5-11th-gen-8-gb-512-gb-ss...
# 203  /dell-inspiron-core-i3-11th-gen-8-gb-256-gb-ss...
# 204  /hp-core-i3-11th-gen-8-gb-256-gb-ssd-windows-1...
#
#                                               img_link  \
# 0    https://rukminim1.flixcart.com/image/312/312/k...
# 1    https://rukminim1.flixcart.com/image/312/312/k...
# 2    https://rukminim1.flixcart.com/image/312/312/k...
# 3    https://rukminim1.flixcart.com/image/312/312/l...
# 4    https://rukminim1.flixcart.com/image/312/312/k...
# ..                                                 ...
# 200  https://rukminim1.flixcart.com/image/312/312/k...
# 201  https://rukminim1.flixcart.com/image/312/312/k...
# 202  https://rukminim1.flixcart.com/image/312/312/k...
# 203  https://rukminim1.flixcart.com/image/312/312/l...
# 204  https://rukminim1.flixcart.com/image/312/312/l...
#
#                                          configuration   website  ratings  \
# 0    Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...  flipkart     1260
# 1    Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...  flipkart      188
# 2    Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...  flipkart     2246
# 3    AMD Ryzen 7 Quad Core Processor16 GB DDR4 RAM6...  flipkart       63
# 4    Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...  flipkart      867
# ..                                                 ...       ...      ...
# 200  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...  flipkart     1768
# 201  Intel Core i7 Processor (11th Gen)16 GB LPDDR4...  flipkart       12
# 202  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...  flipkart      284
# 203  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...  flipkart      222
# 204  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...  flipkart     2112
#
#      reviews   brand
# 0        125  Lenovo
# 1         17  Lenovo
# 2        258    ASUS
# 3          4    ASUS
# 4        108     MSI
# ..       ...     ...
# 200      174    ASUS
# 201        2    ASUS
# 202       30    acer
# 203       21    DELL
# 204      229      HP
#
# [205 rows x 9 columns]

# %%
# 5. fixing the columns values for example price
df['price']=df['price'].apply(lambda x: x.replace(',','').replace('₹',''))

# %%
df
# Out:
#                                           product_name   price  \
# 0    Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...   38990
# 1    Lenovo IdeaPad Gaming Core i5 11th Gen - (8 GB...   54990
# 2    ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...   35990
# 3    ASUS Vivobook 15 Ryzen 7 Quad Core AMD R7-3700...   46990
# 4    MSI Modern 14 Core i5 10th Gen - (8 GB/512 GB ...   41990
# ..                                                 ...     ...
# 200  ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 ...   50990
# 201  ASUS ZenBook Duo 14 (2021) Touch Panel Intel E...  114990
# 202  acer Aspire 5 Core i5 11th Gen - (8 GB/512 GB ...   59090
# 203  DELL Inspiron Core i3 11th Gen - (8 GB/256 GB ...   55490
# 204  HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...   41290
#
#                                                   link  \
# 0    /lenovo-ideapad-3-core-i3-11th-gen-8-gb-512-gb...
# 1    /lenovo-ideapad-gaming-core-i5-11th-gen-8-gb-5...
# 2    /asus-vivobook-15-2022-core-i3-10th-gen-8-gb-5...
# 3    /asus-vivobook-15-ryzen-7-quad-core-amd-r7-370...
# 4    /msi-modern-14-core-i5-10th-gen-8-gb-512-gb-ss...
# ..                                                 ...
# 200  /asus-vivobook-15-2022-core-i5-11th-gen-8-gb-1...
# 201  /asus-zenbook-duo-14-2021-touch-panel-intel-ev...
# 202  /acer-aspire-5-core-i5-11th-gen-8-gb-512-gb-ss...
# 203  /dell-inspiron-core-i3-11th-gen-8-gb-256-gb-ss...
# 204  /hp-core-i3-11th-gen-8-gb-256-gb-ssd-windows-1...
#
#                                               img_link  \
# 0    https://rukminim1.flixcart.com/image/312/312/k...
# 1    https://rukminim1.flixcart.com/image/312/312/k...
# 2    https://rukminim1.flixcart.com/image/312/312/k...
# 3    https://rukminim1.flixcart.com/image/312/312/l...
# 4    https://rukminim1.flixcart.com/image/312/312/k...
# ..                                                 ...
# 200  https://rukminim1.flixcart.com/image/312/312/k...
# 201  https://rukminim1.flixcart.com/image/312/312/k...
# 202  https://rukminim1.flixcart.com/image/312/312/k...
# 203  https://rukminim1.flixcart.com/image/312/312/l...
# 204  https://rukminim1.flixcart.com/image/312/312/l...
#
#                                          configuration   website  ratings  \
# 0    Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...  flipkart     1260
# 1    Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...  flipkart      188
# 2    Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...  flipkart     2246
# 3    AMD Ryzen 7 Quad Core Processor16 GB DDR4 RAM6...  flipkart       63
# 4    Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...  flipkart      867
# ..                                                 ...       ...      ...
# 200  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...  flipkart     1768
# 201  Intel Core i7 Processor (11th Gen)16 GB LPDDR4...  flipkart       12
# 202  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...  flipkart      284
# 203  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...  flipkart      222
# 204  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...  flipkart     2112
#
#      reviews   brand
# 0        125  Lenovo
# 1         17  Lenovo
# 2        258    ASUS
# 3          4    ASUS
# 4        108     MSI
# ..       ...     ...
# 200      174    ASUS
# 201        2    ASUS
# 202       30    acer
# 203       21    DELL
# 204      229      HP
#
# [205 rows x 9 columns]

# %%
df['link'] = df['link'].apply(lambda x: 'https://www.flipkart.com'+x)
df['price'] = df['price'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   205 non-null    object
#  1   price          205 non-null    int32
#  2   link           205 non-null    object
#  3   img_link       205 non-null    object
#  4   configuration  205 non-null    object
#  5   website        205 non-null    object
#  6   ratings        205 non-null    int64
#  7   reviews        205 non-null    int64
#  8   brand          205 non-null    object
# dtypes: int32(1), int64(2), object(6)
# memory usage: 15.2+ KB

# %%
df['brand'].value_counts()
# Out:
# ASUS         70
# HP           33
# DELL         31
# Lenovo       29
# acer         17
# MSI           9
# APPLE         7
# Infinix       5
# RedmiBook     2
# realme        1
# SAMSUNG       1
# Name: brand, dtype: int64

# %% [markdown]
# //pip install matplotlib openpyxl

# %%
df['brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['price'].plot(kind='hist', bins=25, color='red',alpha=0.5,title='Price distribution')
# Out:
# <AxesSubplot:title={'center':'Price distribution'}, ylabel='Frequency'>

# %%
df['reviews'].plot(kind='line', title='Reviews', figsize=(15,5))
# Out:
# <AxesSubplot:title={'center':'Reviews'}>

# %%
# 6. sorting data by column
df.sort_values(by='price', ascending=False,inplace=True)
df.sort_values(by=['reviews','ratings'], ascending=False,inplace=True)
df
# Out:
#                                           product_name   price  \
# 54   realme Book (Slim) Core i3 11th Gen - (8 GB/25...   39990
# 177  Infinix INBook X1 Core i3 10th Gen - (8 GB/256...   29990
# 62   HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/51...   59990
# 185  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...   58990
# 121  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...   57990
# ..                                                 ...     ...
# 196  ASUS ROG Strix Scar 15 (2022) Core i9 12th Gen...  229990
# 41   Lenovo Ideapad Gaming 3 Ryzen 7 Octa Core 5800...   72490
# 88   Lenovo Ideapad Gaming 3 Core i5 11th Gen - (8 ...   66490
# 77   Lenovo Ideapad Gaming 3 Core i5 11th Gen - (8 ...   66490
# 153  ASUS Core i5 10th Gen - (8 GB/256 GB SSD/Windo...   40990
#
#                                                   link  \
# 54   https://www.flipkart.com/realme-book-slim-core...
# 177  https://www.flipkart.com/infinix-inbook-x1-cor...
# 62   https://www.flipkart.com/hp-pavilion-ryzen-5-h...
# 185  https://www.flipkart.com/asus-tuf-gaming-f15-c...
# 121  https://www.flipkart.com/asus-tuf-gaming-f15-c...
# ..                                                 ...
# 196  https://www.flipkart.com/asus-rog-strix-scar-1...
# 41   https://www.flipkart.com/lenovo-ideapad-gaming...
# 88   https://www.flipkart.com/lenovo-ideapad-gaming...
# 77   https://www.flipkart.com/lenovo-ideapad-gaming...
# 153  https://www.flipkart.com/asus-core-i5-10th-gen...
#
#                                               img_link  \
# 54   https://rukminim1.flixcart.com/image/312/312/k...
# 177  https://rukminim1.flixcart.com/image/312/312/k...
# 62   https://rukminim1.flixcart.com/image/312/312/k...
# 185  https://rukminim1.flixcart.com/image/312/312/l...
# 121  https://rukminim1.flixcart.com/image/312/312/k...
# ..                                                 ...
# 196  https://rukminim1.flixcart.com/image/312/312/l...
# 41   https://rukminim1.flixcart.com/image/312/312/k...
# 88   https://rukminim1.flixcart.com/image/312/312/k...
# 77   https://rukminim1.flixcart.com/image/312/312/k...
# 153  https://rukminim1.flixcart.com/image/312/312/l...
#
#                                          configuration   website  ratings  \
# 54   Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...  flipkart     7934
# 177  Intel Core i3 Processor (10th Gen)8 GB LPDDR4X...  flipkart     4786
# 62   AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...  flipkart     7060
# 185  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...  flipkart     4577
# 121  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...  flipkart     4577
# ..                                                 ...       ...      ...
# 196  Intel Core i9 Processor (12th Gen)32 GB DDR5 R...  flipkart        3
# 41   AMD Ryzen 7 Octa Core Processor16 GB DDR4 RAM6...  flipkart        3
# 88   Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...  flipkart        3
# 77   Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...  flipkart        3
# 153  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...  flipkart        3
#
#      reviews    brand
# 54      1250   realme
# 177      865  Infinix
# 62       764       HP
# 185      510     ASUS
# 121      510     ASUS
# ..       ...      ...
# 196        0     ASUS
# 41         0   Lenovo
# 88         0   Lenovo
# 77         0   Lenovo
# 153        0     ASUS
#
# [205 rows x 9 columns]

# %%
# 7. remove duplicates records
df.drop_duplicates(subset=['product_name'],inplace=True)
df.shape
(172, 9)
# 8. grouping data
df.groupby('brand')['price'].min()
# Out:
# brand
# APPLE        112990
# ASUS          22990
# DELL          33090
# HP            29785
# Infinix       24990
# Lenovo        27890
# MSI           41990
# RedmiBook     32990
# SAMSUNG       32990
# acer          24990
# realme        39990
# Name: price, dtype: int32
